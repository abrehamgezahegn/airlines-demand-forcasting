# %% [markdown]
# ## Airline passenger load forecasting using time series prediction

# %% [markdown]
# ## Motivation

# %% [markdown]
# Forecasting air passenger demand is a critical aspect of formulating appropriate operation plans in airport operation. Airport operation not only requires long-term demand forecasting to establish long-term plans, but also short-term demand forecasting for more immediate concerns. Most airports forecast their short-term passenger demand based on experience, which provides limited forecasting accuracy, depending on the level of expertise. For accurate short-term forecasting independent of the level of expertise, it is necessary to create reliable short-term forecasting models and to reflect short-term fluctuations in air passenger demand. (Cite 1)

# %% [markdown]
# ## Problem Statment

# %% [markdown]
# The problem is to predict the passenger count for future months given a history of passenger loan from 1949-1960. This dataset provides monthly totals of a US airline passengers from 1949 to 1960. This dataset is taken from an inbuilt dataset of R called AirPassengers.

# %% [markdown]
# ## Aim of the project

# %% [markdown]
# The aim of the project is to assist airline,investors and other stakeholders in the Airlines industry to be able to decide based on insights drawn from the predictions. The project will demonestrate the use of a machine learning subdomain called **Aritificial Nueral Network** to solve the above problem. The NN we used is **Recurrent Neural Network**. A recurrent neural network (RNN) is a class of artificial neural networks where connections between nodes form a directed graph along a temporal sequence. (Cite 2)

# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
import statsmodels.api as sm
import calendar
from sklearn.preprocessing import MinMaxScaler


from tensorflow.keras.layers import Input, SimpleRNN, GRU, LSTM, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

# %% [markdown]
# ## Download the data

# %% [markdown]
# The dataset used in this project is publicly available in kaggle dataset called Air Passengers by Chirag Kothari. It consists of monthly totals of a US airline passengers from 1949 to 1960.

# %% [markdown]
# ### Download the data using kaggle api

# %% [markdown]
# We can directly download the dataset and upload it to our workspace. But that is inefficient when if the dataset is large. We an use kaggle's api to directly download any dataset found in kaggle.

# %%
# !pip install -q kaggle

# %%
# !ls
# Out:
# AirPassengers.csv   airlines-demand-forecasting-LSTM.ipynb	   kaggle.json
# air-passengers.zip  airlines-demand-forecasting-lstm.ipynb.amltmp

# %%
 # !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/home/azureuser/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ref                                                         title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              229KB  2021-05-26 21:13:45           6131        557  1.0
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-04-28 17:03:01           3459        299  0.9375
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19           1225        106  1.0
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           1959        149  1.0
# promptcloud/careerbuilder-job-listing-2020                  Careerbuilder Job Listing 2020                     42MB  2021-03-05 06:59:52            864         37  1.0
# mathurinache/twitter-edge-nodes                             Twitter Edge Nodes                                342MB  2021-03-08 06:43:04            411         46  1.0
# alsgroup/end-als                                            End ALS Kaggle Challenge                           12GB  2021-04-08 12:16:37            640         96  0.9375
# fatiimaezzahra/famous-iconic-women                          Famous Iconic Women                               838MB  2021-02-28 14:56:00            633         50  0.75
# simiotic/github-code-snippets                               GitHub Code Snippets                                7GB  2021-03-03 11:34:39            127         46  1.0
# nickuzmenkov/nih-chest-xrays-tfrecords                      NIH Chest X-rays TFRecords                         11GB  2021-03-09 04:49:23            520         23  0.9411765
# coloradokb/dandelionimages                                  DandelionImages                                     4GB  2021-02-19 20:03:47            339         19  0.75
# mathurinache/the-lj-speech-dataset                          The LJ Speech Dataset                               3GB  2021-02-15 09:19:54            155         35  1.0
# stuartjames/lights                                          LightS: Light Specularity Dataset                  18GB  2021-02-18 14:32:26             57         23  0.6875
# landrykezebou/lvzhdr-tone-mapping-benchmark-dataset-tmonet  LVZ-HDR Tone Mapping Benchmark Dataset (TMO-Net)   24GB  2021-03-01 05:03:40             72         15  0.6875
# imsparsh/accentdb-core-extended                             AccentDB - Core & Extended                          6GB  2021-02-17 14:22:54             65         21  0.8125
# nickuzmenkov/ranzcr-clip-kfold-tfrecords                    RANZCR CLiP KFold TFRecords                         2GB  2021-02-21 13:29:51             79         17  0.875
# datasnaek/youtube-new                                       Trending YouTube Video Statistics                 201MB  2019-06-03 00:56:47         140859       3969  0.7941176
# zynicide/wine-reviews                                       Wine Reviews                                       51MB  2017-11-27 17:08:04         137088       3072  0.7941176
# datasnaek/chess                                             Chess Game Dataset (Lichess)                        3MB  2017-09-04 03:09:09          18540        725  0.8235294
# residentmario/ramen-ratings                                 Ramen Ratings                                      40KB  2018-01-11 16:04:39          23294        565  0.7058824

# %%
# !kaggle datasets download -d chirag19/air-passengers
# Out:
# air-passengers.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip ./air-passengers.zip
# Out:
# Archive:  ./air-passengers.zip
# replace AirPassengers.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %% [markdown]
# ## Explore Data

# %% [markdown]
# Now that we have downloaded the data we can see what it looks like using libraries like Pandas and Matplotlib.

# %%
df = pandas.read_csv('AirPassengers.csv', engine='python')
# dataset = dataframe.values
# dataset = dataset.astype('float32')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
df.count()
# Out:
# Month          144
# #Passengers    144
# dtype: int64

# %%
df.describe()
# Out:
#        #Passengers
# count   144.000000
# mean    280.298611
# std     119.966317
# min     104.000000
# 25%     180.000000
# 50%     265.500000
# 75%     360.500000
# max     622.000000

# %% [markdown]
# From the start we can see that "#passengers" is not a good name for a column. Let's rename that

# %%
df.rename({'#Passengers':'Passengers'},axis=1,inplace=True)

# %% [markdown]
# ### Check for missing values

# %%
df.isnull().sum()
# Out:
# Month         0
# Passengers    0
# dtype: int64

# %% [markdown]
# ## Analyse the distribution of the data using histogram

# %%
df['Passengers'].hist()

# %%
col = df['Passengers']
def get_box_plot(col, x_label=""):
        # Get the variable to examine

    # Create a Figure
    fig = plt.figure(figsize=(10,4))

    # Plot a histogram
    plt.boxplot(col)

    plt.xlabel(x_label)

    # Add titles and labels
    plt.title('Data Distribution')

    # Show the figure
    fig.show() 

get_box_plot(col);

# %%
def show_density(col, x_label=""):
    from matplotlib import pyplot as plt

    fig = plt.figure(figsize=(10,4))

    # Plot density
    col.plot.density()

    # Add titles and labels
    plt.title('Data Density')
    plt.xlabel(x_label)
    # Show the mean, median, and mode
    plt.axvline(x=col.mean(), color = 'cyan', linestyle='dashed', linewidth = 2)
    plt.axvline(x=col.median(), color = 'red', linestyle='dashed', linewidth = 2)
    plt.axvline(x=col.mode()[0], color = 'yellow', linestyle='dashed', linewidth = 2)

    # Show the figure
    plt.show()

# Get the density of passengers
col = df['Passengers']
show_density(col)

# %% [markdown]
# ### This above visualizations tell us a little about the trend and seasonality of data and only shows the data from the passenger count perspective.But in time series forecasting date plays a very important role.

# %% [markdown]
# ### Bringing time alive

# %%
dates = pandas.date_range(start='1949-01-01', freq='MS',periods=len(df))

# %% [markdown]
# Now we have fully formated date to play with. Let's swap in the values to the dateframe

# %%
df['Month'] = dates.month
df['Year'] = dates.year
df['Date'] = dates

# %%
df['Month'] = df['Month'].apply(lambda x: calendar.month_abbr[x])

# %%
df.set_index('Date',inplace=True)

# %%
df.head()
# Out:
#            Month  Passengers  Year
# Date
# 1949-01-01   Jan         112  1949
# 1949-02-01   Feb         118  1949
# 1949-03-01   Mar         132  1949
# 1949-04-01   Apr         129  1949
# 1949-05-01   May         121  1949

# %% [markdown]
# Now can put the data into time perpective using the data

# %%
plt.figure(figsize=(10,8))
df.groupby('Month')['Passengers'].mean().plot(kind='bar')
plt.show()

# %% [markdown]
# In time series forcasting we are interested in the trend of the data thorugh time. So let's plot a graph that show exactly that.

# %%
df['Passengers']
# Out:
# Date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Passengers, Length: 144, dtype: int64

# %%
plt.figure(figsize=(16,8))
df['Passengers'].plot()
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ### We can see from the graph that the passenger count generally increases. Additionally these is somewhat similar trend that the data shows each year.

# %% [markdown]
# ## More into the trend of the data using statsmodels api

# %% [markdown]
# Decomposition provides a useful abstract model for thinking about time series generally and for better understanding problems during time series analysis and forecasting.

# %%
series = df['Passengers']
result = sm.tsa.seasonal_decompose(series,model='multiplicative',extrapolate_trend=8)

# %% [markdown]
# Trend -  the trend component at time t, which reflects the long-term progression of the series (secular variation).
#
# Seasonal -  the seasonal component at time t, reflecting seasonality (seasonal variation). A seasonal pattern exists when a time series is influenced by seasonal factors.
#
# Residual - the irregular component (or "noise") at time t, which describes random, irregular influences. It represents the residuals or remainder of the time series after the other components have been removed.
#
# Observed - the actual series

# %%
print("Trend:" , result.trend)
print("")
print("")
print("Seasonal:" , result.seasonal)
print("")
print("")
print("Residual: ", result.resid)
print("")
print("")
print("Observed: ",  result.observed)
# Out:
# Trend: Date
# 1949-01-01    120.217593
# 1949-02-01    121.180093
# 1949-03-01    122.142593
# 1949-04-01    123.105093
# 1949-05-01    124.067593
#                  ...
# 1960-08-01    487.628472
# 1960-09-01    492.208333
# 1960-10-01    496.788194
# 1960-11-01    501.368056
# 1960-12-01    505.947917
# Name: Passengers, Length: 144, dtype: float64
#
#
# Seasonal: Date
# 1949-01-01    0.910680
# 1949-02-01    0.889841
# 1949-03-01    1.012001
# 1949-04-01    0.980474
# 1949-05-01    0.979430
#                 ...
# 1960-08-01    1.220025
# 1960-09-01    1.056569
# 1960-10-01    0.920922
# 1960-11-01    0.798061
# 1960-12-01    0.893757
# Name: Passengers, Length: 144, dtype: float64
#
#
# Residual:  Date
# 1949-01-01    1.023020
# 1949-02-01    1.094304
# 1949-03-01    1.067888
# 1949-04-01    1.068754
# 1949-05-01    0.995758
#                 ...
# 1960-08-01    1.018626
# 1960-09-01    0.976825
# 1960-10-01    1.007643
# 1960-11-01    0.974703
# 1960-12-01    0.955341
# Name: Passengers, Length: 144, dtype: float64
#
#
# Observed:  Date
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
#              ...
# 1960-08-01    606
# 1960-09-01    508
# 1960-10-01    461
# 1960-11-01    390
# 1960-12-01    432
# Name: Passengers, Length: 144, dtype: int64

# %%
fig = result.plot()
fig.set_figheight(10)
fig.set_figwidth(8)
fig.suptitle('Passenger count time series decomposed into four components')
# Out:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /anaconda/envs/azureml_py36/lib/python3.6/site-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# Text(0.5, 0.98, 'Passenger count time series decomposed into four components')

# %% [markdown]
# The trend of the graph shows that the passenger count increases each year. And the seasonal graph indicates the passenger count show some increase in some months and decrease in some.

# %% [markdown]
# Let's look closer to seasonality of the passenger count interms of months and years.

# %%
monthly = pandas.pivot_table(data=df,values='Passengers',index='Month',columns='Year')
monthly = monthly.reindex(index=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])

# %%
monthly
# Out:
# Year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# Month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# Dec     118   140   166   194   201   229   278   306   336   337   405   432

# %%
monthly.plot(figsize=(10,6))
plt.show()

# %% [markdown]
# The above graph show that passenger count peaks around July and dips around November. And also show that the passenger count increased thourgh out the years and shows failly similar trend over a year.

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# Now that we have understanding of the data. Let's make preprocess it for use.

# %%
data = df[['Passengers']]
scaler = MinMaxScaler()

# scaler.fit(data[:len(data) // 2])
# scaled_data = scaler.transform(data).flatten()

scaled_data = scaler.fit_transform(data)

# %%
plt.figure(figsize=(12,8))
plt.plot(scaled_data)
plt.xlabel('Year')
plt.ylabel('Scaled Number of Passengers')
plt.show()

# %% [markdown]
# ## Preparing data into sequence of samples

# %% [markdown]
# T - length of one sequence
#
# D - nature of a data sample (1 in our case)

# %%
T = 12
D = 1
X = []
Y = []
for t in range(len(scaled_data) - T):
  x = scaled_data[t:t+T]
  X.append(x)
  y = scaled_data[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T,1)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (132, 12, 1) Y.shape (132, 1)

# %%
N = len(X)

# %% [markdown]
# What we did above is using past 10 month values to predict next month's passenger count. 10 is

# %%
X_train, y_train, X_test , y_test = X[:-N//2], Y[:-N//2] , X[-N//2:], Y[-N//2:]

# %%
X_train
# Out:
# array([[[0.01544402],
#         [0.02702703],
#         [0.05405405],
#         [0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703]],
#
#        [[0.02702703],
#         [0.05405405],
#         [0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552]],
#
#        [[0.05405405],
#         [0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104]],
#
#        [[0.04826255],
#         [0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857]],
#
#        [[0.03281853],
#         [0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556]],
#
#        [[0.05984556],
#         [0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054]],
#
#        [[0.08494208],
#         [0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259]],
#
#        [[0.08494208],
#         [0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313]],
#
#        [[0.06177606],
#         [0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313]],
#
#        [[0.02895753],
#         [0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ]],
#
#        [[0.        ],
#         [0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456]],
#
#        [[0.02702703],
#         [0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502]],
#
#        [[0.02123552],
#         [0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807]],
#
#        [[0.04247104],
#         [0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058]],
#
#        [[0.07142857],
#         [0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309]],
#
#        [[0.05984556],
#         [0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714]],
#
#        [[0.04054054],
#         [0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961]],
#
#        [[0.08687259],
#         [0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413]],
#
#        [[0.12741313],
#         [0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714]],
#
#        [[0.12741313],
#         [0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768]],
#
#        [[0.1042471 ],
#         [0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768]],
#
#        [[0.05598456],
#         [0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015]],
#
#        [[0.01930502],
#         [0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911]],
#
#        [[0.06949807],
#         [0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108]],
#
#        [[0.07915058],
#         [0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112]],
#
#        [[0.08880309],
#         [0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363]],
#
#        [[0.14285714],
#         [0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815]],
#
#        [[0.11389961],
#         [0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467]],
#
#        [[0.13127413],
#         [0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865]],
#
#        [[0.14285714],
#         [0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965]],
#
#        [[0.18339768],
#         [0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722]],
#
#        [[0.18339768],
#         [0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324]],
#
#        [[0.15444015],
#         [0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927]],
#
#        [[0.11196911],
#         [0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ]],
#
#        [[0.08108108],
#         [0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367]],
#
#        [[0.11969112],
#         [0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413]],
#
#        [[0.12934363],
#         [0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517]],
#
#        [[0.14671815],
#         [0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618]],
#
#        [[0.17181467],
#         [0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618]],
#
#        [[0.14864865],
#         [0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625]],
#
#        [[0.15250965],
#         [0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575]],
#
#        [[0.22007722],
#         [0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274]],
#
#        [[0.24324324],
#         [0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977]],
#
#        [[0.26640927],
#         [0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031]],
#
#        [[0.2027027 ],
#         [0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432]],
#
#        [[0.16795367],
#         [0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676]],
#
#        [[0.13127413],
#         [0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371]],
#
#        [[0.17374517],
#         [0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815]],
#
#        [[0.17760618],
#         [0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869]],
#
#        [[0.17760618],
#         [0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019]],
#
#        [[0.25482625],
#         [0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216]],
#
#        [[0.25289575],
#         [0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575]],
#
#        [[0.24131274],
#         [0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174]],
#
#        [[0.26833977],
#         [0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525]],
#
#        [[0.30888031],
#         [0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031]],
#
#        [[0.32432432],
#         [0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938]],
#
#        [[0.25675676],
#         [0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486]],
#
#        [[0.20656371],
#         [0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ]],
#
#        [[0.14671815],
#         [0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274]],
#
#        [[0.18725869],
#         [0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969]],
#
#        [[0.19305019],
#         [0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274]],
#
#        [[0.16216216],
#         [0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274],
#         [0.26640927]],
#
#        [[0.25289575],
#         [0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274],
#         [0.26640927],
#         [0.24903475]],
#
#        [[0.23745174],
#         [0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274],
#         [0.26640927],
#         [0.24903475],
#         [0.31467181]],
#
#        [[0.25096525],
#         [0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274],
#         [0.26640927],
#         [0.24903475],
#         [0.31467181],
#         [0.31853282]],
#
#        [[0.30888031],
#         [0.38223938],
#         [0.36486486],
#         [0.2992278 ],
#         [0.24131274],
#         [0.19111969],
#         [0.24131274],
#         [0.26640927],
#         [0.24903475],
#         [0.31467181],
#         [0.31853282],
#         [0.32046332]]])

# %% [markdown]
# ## About RNNs

# %% [markdown]
# A key difference in RNNs is their memorizing ability because of cyclic / recursive architecture. In ANNs weights are trained on one pass ( feed forward) and back propagation for error correction. In CNNs weights are trained by capturing patterns using kernels. There is no concept of memory in both, one layer’s weights are not dependent on any other layer. RNNs have an unfair advantage of memorization because one layer is dependent on a previous layer. This makes them great at training on sequential data and making forecasts.

# %% [markdown]
# ### ANN

# %% [markdown]
# ![comeon](https://res.cloudinary.com/de5awe7fs/image/upload/v1622206389/Gebeya/Screenshot_from_2021-05-18_18-09-00.png)

# %% [markdown]
# As we can see in ANNs there is no concept of memeory and no relation between the layers

# %% [markdown]
# ## RNNs

# %% [markdown]
# ![](https://res.cloudinary.com/de5awe7fs/image/upload/v1622206389/Gebeya/Screenshot_from_2021-05-18_18-10-21.png)

# %% [markdown]
# We can see that in RNNs the layers are connected to eachother in a way that the previous layer's output is used in the next layer. The left part of image is the actual layer and the right part is the unrolled layer (for explanation purposes).

# %% [markdown]
# ### LSTMs

# %% [markdown]
# LSTMs are types of RNNs that have added complexiy of memorization. RNNs are good for sequential data but they suffer from the vanishing gradient problem. This makes RNNs not be able to hold information far in the past.LSTMs solve this problem by inducing a save/discard method. They filter out irrelevant infromation and only keep what's imporatant. This is achieved by the use of gates that do the filtering.

# %% [markdown]
# ![](https://res.cloudinary.com/de5awe7fs/image/upload/v1622207109/Gebeya/Screenshot_from_2021-05-28_16-04-42.png)

# %% [markdown]
# The calculations of the gates looks as follows.

# %% [markdown]
# ![](https://res.cloudinary.com/de5awe7fs/image/upload/v1622207117/Gebeya/Screenshot_from_2021-05-26_03-23-38.png)

# %% [markdown]
# Now let's construct the NN using LSTM layer from keras tensorflow.

# %%
i = Input(shape=(T, 1))
x = LSTM(5)(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.1),
)

# train the RNN
r = model.fit(
  X_train, y_train,
  epochs=170,
  validation_data=(X_test, y_test),
)
# Out:
# Train on 66 samples, validate on 66 samples
# Epoch 1/170
# 66/66 [==============================] - 1s 22ms/sample - loss: 0.3085 - val_loss: 0.2067
# Epoch 2/170
# 66/66 [==============================] - 0s 410us/sample - loss: 0.0020 - val_loss: 0.0139
# Epoch 150/170
# 66/66 [==============================] - 0s 366us/sample - loss: 0.0014 - val_loss: 0.0099
# Epoch 151/170
# 66/66 [==============================] - 0s 395us/sample - loss: 0.0015 - val_loss: 0.0152
# Epoch 152/170
# 66/66 [==============================] - 0s 393us/sample - loss: 0.0027 - val_loss: 0.0127
# Epoch 153/170
# 66/66 [==============================] - 0s 415us/sample - loss: 0.0016 - val_loss: 0.0079
# Epoch 154/170
# 66/66 [==============================] - 0s 366us/sample - loss: 0.0038 - val_loss: 0.0119
# Epoch 155/170
# 66/66 [==============================] - 0s 407us/sample - loss: 0.0018 - val_loss: 0.0179
# Epoch 156/170
# 66/66 [==============================] - 0s 389us/sample - loss: 0.0021 - val_loss: 0.0102
# Epoch 157/170
# 66/66 [==============================] - 0s 377us/sample - loss: 0.0017 - val_loss: 0.0110
# Epoch 158/170
# 66/66 [==============================] - 0s 385us/sample - loss: 0.0016 - val_loss: 0.0147
# Epoch 159/170
# 66/66 [==============================] - 0s 396us/sample - loss: 0.0016 - val_loss: 0.0097
# Epoch 160/170
# 66/66 [==============================] - 0s 376us/sample - loss: 0.0017 - val_loss: 0.0101
# Epoch 161/170
# 66/66 [==============================] - 0s 390us/sample - loss: 0.0015 - val_loss: 0.0138
# Epoch 162/170
# 66/66 [==============================] - 0s 382us/sample - loss: 0.0017 - val_loss: 0.0088
# Epoch 163/170
# 66/66 [==============================] - 0s 374us/sample - loss: 0.0027 - val_loss: 0.0082
# Epoch 164/170
# 66/66 [==============================] - 0s 390us/sample - loss: 0.0017 - val_loss: 0.0179
# Epoch 165/170
# 66/66 [==============================] - 0s 380us/sample - loss: 0.0033 - val_loss: 0.0115
# Epoch 166/170
# 66/66 [==============================] - 0s 376us/sample - loss: 0.0016 - val_loss: 0.0077
# Epoch 167/170
# 66/66 [==============================] - 0s 383us/sample - loss: 0.0035 - val_loss: 0.0103
# Epoch 168/170
# 66/66 [==============================] - 0s 450us/sample - loss: 0.0018 - val_loss: 0.0152
# Epoch 169/170
# 66/66 [==============================] - 0s 407us/sample - loss: 0.0023 - val_loss: 0.0101
# Epoch 170/170
# 66/66 [==============================] - 0s 379us/sample - loss: 0.0015 - val_loss: 0.0090

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ## Evaluating our model

# %%
# One-step forecast using true targets
outputs = model.predict(X)
print(outputs.shape)
predictions = outputs[:,0]

plt.plot( Y, label='targets')
plt.plot(predictions, label='predictions')
plt.legend()
plt.show()
# Out:
# (132, 1)

# %%
# Multi-step forecast
validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, T, 1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %% [markdown]
# References
#
# 1. https://www.sciencedirect.com/science/article/abs/pii/S0926580516301303
# 2. https://en.wikipedia.org/wiki/Recurrent_neural_network
